# %%
import sagemaker
from sagemaker import get_execution_role
from sagemaker.session import Session

# Setup session
sess = sagemaker.Session()

# S3 bucket for saving code and model artifacts.
# Feel free to specify a different bucket here.
bucket = sess.default_bucket()

# Location to put your custom code.

custom_code_upload_location = "customcode"

# IAM execution role that gives Amazon SageMaker access to resources in your AWS account.
# You can use the Amazon SageMaker Python SDK to get the role from the notebook environment.
role = get_execution_role()

# %%
from sagemaker.pytorch import PyTorch

source_dir = 'arxiv'
CODE_PATH = "gnn.py"
account = sess.boto_session.client("sts").get_caller_identity()["Account"]
region = sess.boto_session.region_name

params = {'epochs' : 100, 'runs' : 5, 'use_sage' : True}

task_tags = [{"Key": "ML Task", "Value": "DGL"}]
estimator = PyTorch(
    source_dir=source_dir,
    entry_point=CODE_PATH,
    role=role,
    instance_count=1,
    instance_type="ml.g4dn.xlarge",  # 'ml.c4.2xlarge '
    framework_version="1.8.0",
    py_version="py3",
    debugger_hook_config=False,
    tags=task_tags,
    hyperparameters=params,
    sagemaker_session=sess,
)

# %%
estimator.fit()
# Out:
# 2022-04-16 05:17:30 Starting - Starting the training job...
# 2022-04-16 05:17:55 Starting - Preparing the instances for trainingProfilerReport-1650086250: InProgress
# ......
# 2022-04-16 05:19:00 Downloading - Downloading input data...
# 2022-04-16 05:19:16 Training - Downloading the training image...........................
# 2022-04-16 05:23:56 Training - Training image download completed. Training in progress.bash: cannot set terminal process group (-1): Inappropriate ioctl for device
# bash: no job control in this shell
# 2022-04-16 05:23:50,143 sagemaker-training-toolkit INFO     Imported framework sagemaker_pytorch_container.training
# 2022-04-16 05:23:50,165 sagemaker_pytorch_container.training INFO     Block until all host DNS lookups succeed.
# 2022-04-16 05:23:50,172 sagemaker_pytorch_container.training INFO     Invoking user training script.
# 2022-04-16 05:23:50,501 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /opt/conda/bin/python3.6 -m pip install -r requirements.txt
# Collecting torch-scatter
#   Downloading torch_scatter-2.0.9.tar.gz (21 kB)
# Collecting torch-sparse
#   Downloading torch_sparse-0.6.12.tar.gz (43 kB)
# Collecting torch-geometric
#   Downloading torch_geometric-2.0.3.tar.gz (370 kB)
# Collecting ogb
#   Downloading ogb-1.3.3-py3-none-any.whl (78 kB)
# Collecting outdated>=0.2.0
#   Downloading outdated-0.2.1-py3-none-any.whl (7.5 kB)
# Requirement already satisfied: numpy>=1.16.0 in /opt/conda/lib/python3.6/site-packages (from ogb->-r requirements.txt (line 4)) (1.19.1)
# Requirement already satisfied: pandas>=0.24.0 in /opt/conda/lib/python3.6/site-packages (from ogb->-r requirements.txt (line 4)) (1.1.5)
# Requirement already satisfied: six>=1.12.0 in /opt/conda/lib/python3.6/site-packages (from ogb->-r requirements.txt (line 4)) (1.15.0)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.6/site-packages (from ogb->-r requirements.txt (line 4)) (1.8.0)
# Requirement already satisfied: scikit-learn>=0.20.0 in /opt/conda/lib/python3.6/site-packages (from ogb->-r requirements.txt (line 4)) (0.24.1)
# Requirement already satisfied: tqdm>=4.29.0 in /opt/conda/lib/python3.6/site-packages (from ogb->-r requirements.txt (line 4)) (4.51.0)
# Requirement already satisfied: urllib3>=1.24.0 in /opt/conda/lib/python3.6/site-packages (from ogb->-r requirements.txt (line 4)) (1.25.11)
# Requirement already satisfied: requests in /opt/conda/lib/python3.6/site-packages (from outdated>=0.2.0->ogb->-r requirements.txt (line 4)) (2.25.1)
# Collecting littleutils
#   Downloading littleutils-0.2.2.tar.gz (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.7.3 in /opt/conda/lib/python3.6/site-packages (from pandas>=0.24.0->ogb->-r requirements.txt (line 4)) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /opt/conda/lib/python3.6/site-packages (from pandas>=0.24.0->ogb->-r requirements.txt (line 4)) (2021.1)
# Requirement already satisfied: joblib>=0.11 in /opt/conda/lib/python3.6/site-packages (from scikit-learn>=0.20.0->ogb->-r requirements.txt (line 4)) (1.0.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.6/site-packages (from scikit-learn>=0.20.0->ogb->-r requirements.txt (line 4)) (2.1.0)
# Requirement already satisfied: scipy>=0.19.1 in /opt/conda/lib/python3.6/site-packages (from scikit-learn>=0.20.0->ogb->-r requirements.txt (line 4)) (1.5.4)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.6/site-packages (from torch>=1.6.0->ogb->-r requirements.txt (line 4)) (3.7.4.3)
# Requirement already satisfied: dataclasses in /opt/conda/lib/python3.6/site-packages (from torch>=1.6.0->ogb->-r requirements.txt (line 4)) (0.8)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.6/site-packages (from torch-geometric->-r requirements.txt (line 3)) (2.5)
# Collecting rdflib
#   Downloading rdflib-5.0.0-py3-none-any.whl (231 kB)
# Collecting googledrivedownloader
#   Downloading googledrivedownloader-0.4-py2.py3-none-any.whl (3.9 kB)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.6/site-packages (from torch-geometric->-r requirements.txt (line 3)) (2.11.3)
# Requirement already satisfied: pyparsing in /opt/conda/lib/python3.6/site-packages (from torch-geometric->-r requirements.txt (line 3)) (2.4.7)
# Collecting yacs
#   Downloading yacs-0.1.8-py3-none-any.whl (14 kB)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.6/site-packages (from torch-geometric->-r requirements.txt (line 3)) (5.4.1)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.6/site-packages (from jinja2->torch-geometric->-r requirements.txt (line 3)) (1.1.1)
# Requirement already satisfied: decorator>=4.3.0 in /opt/conda/lib/python3.6/site-packages (from networkx->torch-geometric->-r requirements.txt (line 3)) (4.4.2)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.6/site-packages (from requests->outdated>=0.2.0->ogb->-r requirements.txt (line 4)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.6/site-packages (from requests->outdated>=0.2.0->ogb->-r requirements.txt (line 4)) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.6/site-packages (from requests->outdated>=0.2.0->ogb->-r requirements.txt (line 4)) (2.10)
# Building wheels for collected packages: torch-geometric, torch-scatter, torch-sparse, littleutils
#   Building wheel for torch-geometric (setup.py): started
#   Building wheel for torch-geometric (setup.py): finished with status 'done'
#   Created wheel for torch-geometric: filename=torch_geometric-2.0.3-py3-none-any.whl size=581953 sha256=ef31aeb6e321973a044b613f70110d20811e0f04eb7e269559d58cffebdece80
#   Stored in directory: /root/.cache/pip/wheels/d2/48/63/193500a1360033fb617b90aede62d33ef14dc8e5f5c5f0972a
#   Building wheel for torch-scatter (setup.py): started
#   Building wheel for torch-scatter (setup.py): still running...
#   Building wheel for torch-scatter (setup.py): still running...
#   Building wheel for torch-scatter (setup.py): still running...
#   Building wheel for torch-scatter (setup.py): still running...
#   Building wheel for torch-scatter (setup.py): still running...
#   Building wheel for torch-scatter (setup.py): still running...
#   Building wheel for torch-scatter (setup.py): finished with status 'done'
#   Created wheel for torch-scatter: filename=torch_scatter-2.0.9-cp36-cp36m-linux_x86_64.whl size=6823730 sha256=927602c0b83a44e152f037fa0e8e61ed01f90d1f454a484e74e7584389f8abf7
#   Stored in directory: /root/.cache/pip/wheels/48/f1/07/fe02c3b61f43390870ff365ee2a1d690c2becf263ab3328273
#   Building wheel for torch-sparse (setup.py): started
#   Building wheel for torch-sparse (setup.py): still running...
#   Building wheel for torch-sparse (setup.py): still running...
#   Building wheel for torch-sparse (setup.py): still running...
#   Building wheel for torch-sparse (setup.py): still running...
#   Building wheel for torch-sparse (setup.py): still running...
#   Building wheel for torch-sparse (setup.py): still running...
#   Building wheel for torch-sparse (setup.py): still running...
#   Building wheel for torch-sparse (setup.py): still running...

# %%
predictor = pytorch_estimator.deploy(instance_type='ml.m4.xlarge',
                                     initial_instance_count=1)

# %%
response = predictor.predict(data)

# %%
# ?
dataset = PygNodePropPredDataset(name='ogbn-arxiv',
                                     transform=T.ToSparseTensor())

data = dataset[0]
data.adj_t = data.adj_t.to_symmetric()
data = data.to(device)

split_idx = dataset.get_idx_split()
train_idx = split_idx['train'].to(device)


out = model(data.x, data.adj_t)
y_pred = out.argmax(dim=-1, keepdim=True)

train_acc = evaluator.eval({
    'y_true': data.y[split_idx['train']],
    'y_pred': y_pred[split_idx['train']],
})['acc']
valid_acc = evaluator.eval({
    'y_true': data.y[split_idx['valid']],
    'y_pred': y_pred[split_idx['valid']],
})['acc']
test_acc = evaluator.eval({
    'y_true': data.y[split_idx['test']],
    'y_pred': y_pred[split_idx['test']],
})['acc']

return train_acc, valid_acc, test_acc
